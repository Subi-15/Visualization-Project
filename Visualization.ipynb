# %%
import pandas as pd
data = pd.read_csv('/content/test.csv')

# %%
data.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %%
list(data.columns)
# Out:
# ['PassengerId',
#  'Pclass',
#  'Name',
#  'Sex',
#  'Age',
#  'SibSp',
#  'Parch',
#  'Ticket',
#  'Fare',
#  'Cabin',
#  'Embarked']

# %%
import seaborn as sns
sns.scatterplot(x="Cabin", y="Age", data=data)

# %%
sns.histplot(x=data['Ticket'])

# %%
sns.histplot(x=data['Age'])

# %%
import pandas as pd
import seaborn as sns  # for the data


data.groupby('Sex').Age.value_counts().plot(kind='bar', color=['C0', 'C1'], stacked=True)

# %%
sns.boxplot(y=data['Age'],  color='lightgreen', showmeans=True);

# %%
sns.boxplot(x = data['Sex'],
            y = data['Age'],
            
            palette = 'Set2')

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt
labels = ["Age","Sex","Ticket"]
sizes = [50,50,50]
plt.pie(sizes,labels=labels,explode=(0.1,0.1,0.1))
plt.axis("equal")
plt.show()

# %%
data.plot(kind="scatter",x="Ticket",y="Fare")

# %%
sns.FacetGrid(data,hue="Sex",size=5).map(sns.kdeplot,"Age").add_legend()
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/axisgrid.py:337: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
